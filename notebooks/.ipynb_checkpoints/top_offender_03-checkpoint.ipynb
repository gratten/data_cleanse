# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
import os
os.chdir('C:\\Users\\WDG1DCR\\Desktop\\my_projects\\data_analysis\\data_cleanse')
# os.chdir('C:\\Users\\gratten\\Documents\\python\\projects\\data_cleanse')

import pandas as pd
from prep import filter
from prep import sort
from plot import bar
from utility import generate

# %%
fileName = 'filelist_7_15'
df_og = pd.read_csv('datasets/' + fileName + '.csv', sep=';')

# %%
df = filter.sld(df_og)

# %%
dups = df[df.duplicated(['name_low'], keep=False)]
dups = dups.sort_values(['name_low'])

# %%
# dups = dups.reset_index()
dups.reset_index(inplace=True, drop=True)

# %%
dups.head()
# Out:
#                          Name  Format    size             modified  \
# 0            #40 CHAIN.SLDASM  SLDASM  98,273  10/12/2018 13:43:23
# 1            #40 Chain.SLDASM  SLDASM  92,370  06/19/2020 16:04:50
# 2      #40 PIN RIVETED.SLDPRT  SLDPRT  55,996  02/24/2017 15:31:59
# 3      #40 PIN RIVETED.SLDPRT  SLDPRT  52,842  11/20/2014 10:11:00
# 4  #40 PIN RIVETEDRev2.SLDPRT  SLDPRT  52,722  11/19/2014 22:34:28
#
#                created                                               path  \
# 0  02/22/2016 01:04:05  R:\Doc\SolidWorks\SolidWorks Palette\Palette P...
# 1  02/21/2016 22:51:10                         R:\Doc\SolidWorks\CONVEYOR
# 2  02/22/2016 01:04:05  R:\Doc\SolidWorks\SolidWorks Palette\Palette P...
# 3  02/21/2016 23:05:11       R:\Doc\SolidWorks\HS4989 - QUAKER MAID MEATS
# 4  02/21/2016 22:59:28  R:\Doc\SolidWorks\HS4836-4 TWO FLAP CLOSER (ME...
#
#                      name_low
# 0            #40 chain.sldasm
# 1            #40 chain.sldasm
# 2      #40 pin riveted.sldprt
# 3      #40 pin riveted.sldprt
# 4  #40 pin rivetedrev2.sldprt

# %%
top_offenders = dups['path'].value_counts().index.to_list()

# %%
# input: data (trimmed dups), num, cut off indicator (ie valCounts > 5)
# output: top_offenders list at level 2, in reguards to top_offender[num]
def get_top_offenders(dups, num, limit):
    
    # list of all files in directory top_offender[num]
    file_list = []
    for i in range(len(dups['path'])):
        if dups['path'][i] == top_offenders[num]:
            file_list.append(dups['name_low'].iloc[i])
    
    # dictionary of all files in directory top_offender[num] and all other associated paths
    # {filename: [path1, path2, etc], filename: [path1, path2, etc]}
    file_paths = {}
    for file in file_list:
        dups_trimmed = dups[(dups['name_low'] == file)]
        path_list = []
        for path in dups_trimmed['path']:
            path_list.append(path)
        file_paths[file] = path_list
        
    # create a list of all paths involved, merged together
    partner_paths = []
    for k, v in file_paths.items():
        for i in v:
            if i != top_offenders[num]:
                partner_paths.append(i)
    
    # create series and use value_counts
    partner_paths_series = pd.Series(partner_paths)
    val_count = partner_paths_series.value_counts()
    
    # trim top_offenders2 list, per user input (> x associated paths)
    top_offenders2 = []
    for i in range(len(val_count)):
        if val_count[i] > limit:
            top_offenders2.append(val_count.index[i])
    
    return top_offenders2, file_paths

# %%
def build_data(offender, file_paths):
    
    # trim file_paths to only relevent files
    file_paths_trimmed = {}
    for k, v in file_paths.items():
        if offender in v:
            file_paths_trimmed[k] = v
            
    totalFiles = len(file_paths_trimmed.keys())
            
    occur_list = []
    for k, v in file_paths_trimmed.items():
        if len(v) not in occur_list:
                occur_list.append(len(v))

    occur_dict = {}
    for i in occur_list:
        occur_dict[i] = 0
        for v in file_paths_trimmed.values():
            if i == len(v):
                occur_dict[i] += 1
                
    num_list = []
    occur_list = []
    for i in range(len(occur_dict)):
        key = min(occur_dict.keys())
        num_list.append(key)
        value = occur_dict.pop(key)
        occur_list.append(value) 
            
    return num_list, occur_list, totalFiles

# %%
def chart_em(num_list, occur_list, totalFiles, titleA, titleB, i):
    
    df = pd.DataFrame({'other paths':num_list, 'occurences':occur_list})
    title = f'{titleA}\n{titleB}\nTotal Files: {totalFiles}\nChart: {i}'
    ax = df.plot.bar(x='other paths', y='occurences', rot=0, figsize=(10, 4), title = title)

# %%
def build_data2(num, chart_num, top_offenders, top_offenders2, file_paths):
    titleA = top_offenders[num]
    titleB = top_offenders2[chart_num]
    
    file_paths_trimmed = {}
    for k, v in file_paths.items():
        if titleB in v:
            if len(v) == quant: 
                file_paths_trimmed[k] = v
                
    path_list = []
    for v in file_paths_trimmed.values():
        for i in v:
            path_list.append(i)
            
    path_list = pd.Series(path_list)
    
    occurence_list = path_list.value_counts().to_list()
    
    path_list = path_list.value_counts().index.to_list()
    
    return occurence_list, path_list, file_paths_trimmed

# %%
def chart_em2(list1, list2, titleA):
    df = pd.DataFrame({'other paths':list1, 'occurences':list2})
    title = f'{titleA}'
    ax = df.plot.barh(x='other paths', y='occurences', rot=0, figsize=(3, 7), title = title)

# %%
############################################
# choose top offender
############################################
num = 0
limit = 20

titleA = top_offenders[num]

top_offenders2, file_paths = get_top_offenders(dups, num, limit)

# %%
numlist_list = []
occurlist_list =[]
totalFiles_list = []
for i in top_offenders2:
    numlist, occurlist, totalFiles = build_data(i, file_paths)
    numlist_list.append(numlist)
    occurlist_list.append(occurlist)
    totalFiles_list.append(totalFiles)

# %%
for i in range(len(numlist_list)):
    titleB = top_offenders2[i]
    chart_em(numlist_list[i], occurlist_list[i], totalFiles_list[i], titleA, titleB, i)

# %%
############################################
# choose chart num and column for file list
############################################
chart_num = 0
quant = 4

# %%
occurence_list, path_list, file_paths_trimmed = build_data2(num, chart_num, top_offenders, top_offenders2, file_paths)

# %%
chart_em2(path_list, occurence_list, titleA)

# %%
for i in path_list:
    print(i)
# Out:
# R:\Doc\SolidWorks\Celox feeders\Study 3, Mid-range\9in Celox feeder
# R:\Doc\SolidWorks\HS4937, CELOX
# R:\Doc\SolidWorks\HS4975 Nestle Gaffney Celox 9H\9in Celox feeder for Decatur 25 july 2008
# R:\Doc\SolidWorks\HS4973 Kraft Tech Center (Celox)\15 INCH FEEDER
# R:\Doc\SolidWorks\P6153 CELOX AP\JUNK
# R:\Doc\SolidWorks\HS4973 Kraft Tech Center (Celox)
# R:\Doc\SolidWorks\HS4998 HEINZ GATEWAY\Standard 9inch Feeder

# %%
file_list = []
for k in file_paths_trimmed.keys():
    file_list.append(k)

# %%
dups_trimmed = dups[dups['name_low'].isin(file_list)]

# %%
for i in range(len(dups_trimmed['size'])):    
    value1 = dups_trimmed['size'].iloc[i]
    value1 = value1.replace(',','')
    value1 = int(value1)
    dups_trimmed['size'].iloc[i] = value1
# Out:
# C:\Users\WDG1DCR\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
dups_trimmed = dups_trimmed.sort_values(by=['size'], ascending=False)

# %%
dups_trimmed.reset_index(inplace=True, drop=True)

# %%
dups_trimmed.head(25)
# Out:
#                                                  Name  Format    size  \
# 0   SPRING - COMP - LEE LC 051G 09 S - (N8700031)....  SLDPRT  561258
# 1   SPRING - COMP - LEE LC 051G 09 S - (N8700031)....  SLDPRT  560983
# 2   SPRING - COMP - LEE LC 051G 09 S - (N8700031)....  SLDPRT  560178
# 3   SPRING - COMP - LEE LC 051G 09 S - (N8700031)....  SLDPRT  549368
# 4                                 4176-360-005.SLDPRT  SLDPRT  509429
# 5                                 4176-360-005.SLDPRT  SLDPRT  507445
# 6                                 4176-360-000.SLDASM  SLDASM  485462
# 7                                 4176-360-000.SLDASM  SLDASM  480007
# 8                                 4176-360-000.SLDASM  SLDASM  478063
# 9   SPRING - COMP - LEE LC-026E-14S - (N8700021).s...  SLDPRT  460396
# 10  SPRING - COMP - LEE LC-026E-14S - (N8700021).s...  SLDPRT  460091
# 11  SPRING - COMP - LEE LC-026E-14S - (N8700021).s...  SLDPRT  459921
# 12                                4176-360-005.SLDPRT  SLDPRT  456340
# 13                                4176-360-005.SLDPRT  SLDPRT  454639
# 14  SPRING - COMP - LEE LC-026E-14S - (N8700021).S...  SLDPRT  437718
# 15                                4176-360-000.SLDASM  SLDASM  402640
# 16                                4176-605-001.sldasm  SLDASM  328704
# 17                ELESA DD52 Indicator (agile).sldprt  SLDPRT  317583
# 18                ELESA DD52 Indicator (agile).sldprt  SLDPRT  301607
# 19                ELESA DD52 Indicator (agile).SLDPRT  SLDPRT  300789
# 20                ELESA DD52 Indicator (agile).sldprt  SLDPRT  300603
# 21                                4176-605-001.SLDASM  SLDASM  246071
# 22                                4176-605-002.SLDASM  SLDASM  240200
# 23                                4176-360-002.sldprt  SLDPRT  231370
# 24                                4176-360-002.sldprt  SLDPRT  231058
#
#                modified              created  \
# 0   11/20/2014 09:50:02  02/21/2016 23:04:51
# 1   11/20/2014 06:25:31  02/21/2016 23:03:08
# 2   11/18/2014 16:47:10  02/21/2016 22:47:16
# 3   10/25/2016 10:49:03  02/21/2016 23:00:41
# 8                                 4176-360-000.sldasm
# 9   spring - comp - lee lc-026e-14s - (n8700021).s...
# 10  spring - comp - lee lc-026e-14s - (n8700021).s...
# 11  spring - comp - lee lc-026e-14s - (n8700021).s...
# 12                                4176-360-005.sldprt
# 13                                4176-360-005.sldprt
# 14  spring - comp - lee lc-026e-14s - (n8700021).s...
# 15                                4176-360-000.sldasm
# 16                                4176-605-001.sldasm
# 17                elesa dd52 indicator (agile).sldprt
# 18                elesa dd52 indicator (agile).sldprt
# 19                elesa dd52 indicator (agile).sldprt
# 20                elesa dd52 indicator (agile).sldprt
# 21                                4176-605-001.sldasm
# 22                                4176-605-002.sldasm
# 23                                4176-360-002.sldprt
# 24                                4176-360-002.sldprt

# %%
for i in dups_trimmed['Name']:
    print(i)
# Out:
# SPRING - COMP - LEE LC 051G 09 S - (N8700031).sldprt
# SPRING - COMP - LEE LC 051G 09 S - (N8700031).sldprt
# SPRING - COMP - LEE LC 051G 09 S - (N8700031).sldprt
# SPRING - COMP - LEE LC 051G 09 S - (N8700031).SLDPRT
# 4176-360-005.SLDPRT
# 4176-360-005.SLDPRT
# 4176-360-000.SLDASM
# 4176-360-000.SLDASM
# 4176-360-000.SLDASM
# SPRING - COMP - LEE LC-026E-14S - (N8700021).sldprt
# SPRING - COMP - LEE LC-026E-14S - (N8700021).sldprt
# SPRING - COMP - LEE LC-026E-14S - (N8700021).sldprt
# 4176-360-005.SLDPRT
# 4176-360-005.SLDPRT
# SPRING - COMP - LEE LC-026E-14S - (N8700021).SLDPRT
# 4176-360-000.SLDASM
# 4176-605-001.sldasm
# ELESA DD52 Indicator (agile).sldprt
# ELESA DD52 Indicator (agile).sldprt
# ELESA DD52 Indicator (agile).SLDPRT
# ELESA DD52 Indicator (agile).sldprt
# 4176-605-001.SLDASM
# 4176-605-002.SLDASM
# 4176-360-002.sldprt
# 4176-360-002.sldprt
# 4176-360-002.sldprt
# 4176-605-001.sldasm
# 4176-360-002.sldprt
# 4176-605-002.sldasm
# 4176-605-001.sldasm
# HP820-K3-25 CHAIN LINK.SLDPRT
# 4176-605-002.sldasm
# 4176-605-002.sldasm
# HP820-K3-25 CHAIN LINK.SLDPRT
# HP820-K3-25 CHAIN LINK.SLDPRT
# HP820-K3-25 CHAIN LINK.SLDPRT
# 4334-510-009.SLDPRT
# 4334-510-009.SLDPRT
# 4334-510-009.SLDPRT
# Oilite Flanged Bush type AMF(Agile).SLDPRT
# Oilite Flanged Bush type AMF(Agile).SLDPRT
# Oilite Flanged Bush type AMF(Agile).SLDPRT
# Oilite Flanged Bush type AMF(Agile).sldprt
# 4176-510-010.sldprt
# 4334-510-009.SLDPRT
# 4176-510-010.sldprt
# 4176-510-010.sldprt
# 4176-510-010.sldprt
# 4176-360-007.SLDASM
# 4176-360-007.SLDASM
